# %%
import sys
print(sys.executable)
# Out:
# C:\Users\MANASVI_P\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import os

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

plt.style.use("ggplot")

pd.set_option("display.max_columns", None)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(clean_df["age"], bins=30, kde=True, ax=axes[0])
axes[0].set_title("Age Distribution")

sns.boxplot(x=clean_df["age"], ax=axes[1])
axes[1].set_title("Age Box Plot")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 fig, axes = plt.subplots(1, 2, figsize=(12, 5))
#       2
# ----> 3 sns.histplot(clean_df["age"], bins=30, kde=True, ax=axes[0])
#       4 axes[0].set_title("Age Distribution")
#       5
#       6 sns.boxplot(x=clean_df["age"], ax=axes[1])
#
# NameError: name 'clean_df' is not defined
